# %% [markdown]
# # Project 1- Lung Cancer Classification using Computerized Tomography (CT)

# %% [markdown]
# CRISP-DM (Cross-Industry Standard Process for Data Mining)

# %% [markdown]
# **I. Business Understanding**

# %% [markdown]
# **II. Data Understanding**

# %% [markdown]
# **III. Data Preparation**

# %% [markdown]
# **IV. Modeling**

# %% [markdown]
# **V. Evaluation**
